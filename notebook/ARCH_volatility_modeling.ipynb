# %% [markdown]
# <a href="https://colab.research.google.com/github/saritmaitra/AL-VAR-VECM-/blob/main/ARCH_volatility_modeling.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Volatility modelling

# %% [markdown]
# ## Testing for ARCH effects in exchange rate returns

# %%
import pandas as pd
import numpy as np 
import matplotlib.pyplot as plt 
import datetime as dt
import seaborn as sns
# %matplotlib inline
from statsmodels.stats.diagnostic import het_arch
from statsmodels.compat import lzip
import statsmodels.api as sm
import pandas.util.testing as tm
# Out:
# /usr/local/lib/python3.6/dist-packages/statsmodels/tools/_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-a6601cfe-add9-4caa-a5e0-8a7b240b8bb8" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-a6601cfe-add9-4caa-a5e0-8a7b240b8bb8">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving AL_final_data.csv to AL_final_data.csv

# %%
data = pd.read_csv("AL_final_data.csv")
data.drop(['Unnamed: 0'], axis=1, inplace=True)
data.tail()
# Out:
#                  timestamp       es    eur_usd  ...       gc        nq      usd_jpy
# 29340  2020-05-29 20:56:00  3027.25  1111740.0  ...  1731.50  9588.625  107675000.0
# 29341  2020-05-29 20:57:00  3027.25  1111750.0  ...  1731.20  9588.500  107830000.0
# 29342  2020-05-29 20:58:00  3027.25  1111650.0  ...  1731.45  9588.625  107830000.0
# 29343  2020-05-29 20:59:00  3027.25  1113400.0  ...  1731.30  9587.375  107835000.0
# 29344  2020-05-29 21:00:00  3027.25  1113400.0  ...  1731.35  9591.125  107835000.0
#
# [5 rows x 7 columns]

# %%
data = data.set_index('timestamp')
data
# Out:
#                            es    eur_usd  ...        nq      usd_jpy
# timestamp                                 ...
# 2020-05-01 00:00:00  2877.125  1094465.0  ...  8846.125  107301000.0
# 2020-05-01 00:01:00  2875.375  1094215.0  ...  8841.250  107368000.0
# 2020-05-01 00:02:00  2874.625  1094165.0  ...  8837.750  107376500.0
# 2020-05-01 00:03:00  2874.125  1094115.0  ...  8836.750  107381500.0
# 2020-05-01 00:04:00  2875.250  1094190.0  ...  8841.125  107376500.0
# ...                       ...        ...  ...       ...          ...
# 2020-05-29 20:56:00  3027.250  1111740.0  ...  9588.625  107675000.0
# 2020-05-29 20:57:00  3027.250  1111750.0  ...  9588.500  107830000.0
# 2020-05-29 20:58:00  3027.250  1111650.0  ...  9588.625  107830000.0
# 2020-05-29 20:59:00  3027.250  1113400.0  ...  9587.375  107835000.0
# 2020-05-29 21:00:00  3027.250  1113400.0  ...  9591.125  107835000.0
#
# [29345 rows x 6 columns]

# %%
# Converting the index as date
data.index = pd.to_datetime(data.index)
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 29345 entries, 2020-05-01 00:00:00 to 2020-05-29 21:00:00
# Data columns (total 6 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   es       29345 non-null  float64
#  1   eur_usd  29345 non-null  float64
#  2   gbp_usd  29345 non-null  float64
#  3   gc       29345 non-null  float64
#  4   nq       29345 non-null  float64
#  5   usd_jpy  29345 non-null  float64
# dtypes: float64(6)
# memory usage: 1.6 MB

# %%
data = data.resample('B').ffill().bfill()
data.tail()
# Out:
#                   es    eur_usd    gbp_usd       gc        nq      usd_jpy
# timestamp
# 2020-05-25  2967.875  1090835.0  1218635.0  1730.35  9460.000  107750500.0
# 2020-05-26  2982.125  1090080.0  1220010.0  1727.10  9508.875  107692000.0
# 2020-05-27  2993.125  1097845.0  1233230.0  1704.75  9404.625  107489500.0
# 2020-05-28  3041.375  1101505.0  1226240.0  1708.30  9439.500  107805500.0
# 2020-05-29  3024.750  1107780.0  1231910.0  1721.40  9416.625  107630500.0

# %%
data.isnull().sum()
# Out:
# es         0
# eur_usd    0
# gbp_usd    0
# gc         0
# nq         0
# usd_jpy    0
# dtype: int64

# %%
# Calculate daily returns:
returns = 100 * data.pct_change().dropna()
returns
# Out:
#                   es   eur_usd   gbp_usd        gc        nq   usd_jpy
# timestamp
# 2020-05-04 -3.406178  0.111470 -1.004658  0.686971 -2.917944 -0.506519
# 2020-05-05  1.911573 -0.477783 -0.061020  0.248902  2.782953 -0.069316
# 2020-05-06  1.151911 -0.596084 -0.020085  0.046736  1.400532 -0.240431
# 2020-05-07 -0.999171 -0.366253 -0.957019 -1.185367  0.251379 -0.210003
# 2020-05-08  2.137506  0.336580  0.378069  1.926429  2.035244  0.180314
# 2020-05-11  1.372168  0.003691  0.343507 -0.959504  1.026677  0.485455
# 2020-05-12 -0.664028 -0.261615 -0.670565 -0.523913  0.325684  0.642588
# 2020-05-13 -2.888118  0.351122 -0.635357  0.432518 -2.765393 -0.401028
# 2020-05-14 -0.697172 -0.223582 -0.118744  1.204078 -0.272906 -0.246811
# 2020-05-15  1.510775 -0.150621 -0.048616  0.822116  1.277973  0.427960
# 2020-05-18  0.437733  0.126323 -1.207410  1.441328  0.563716 -0.126211
# 2020-05-19  2.867727  0.877140  0.949930 -1.669922  1.906710  0.141759
# 2020-05-20 -0.923611  0.117279  0.477463  0.716732 -0.231537  0.417224
# 2020-05-21  1.342741  0.464906 -0.212920  0.005716  1.726474 -0.210991
# 2020-05-22 -0.430398 -0.235021 -0.055183 -1.334591 -0.804410  0.031599
# 2020-05-25  0.618723 -0.398103 -0.318602  0.237509  0.608864  0.111027
# 2020-05-26  0.480142 -0.069213  0.112831 -0.187823  0.516649 -0.054292
# 2020-05-27  0.368864  0.712333  1.083598 -1.294077 -1.096344 -0.188036
# 2020-05-28  1.612028  0.333380 -0.566804  0.208242  0.370828  0.293982
# 2020-05-29 -0.546628  0.569675  0.462389  0.766844 -0.242333 -0.162329

# %%
for c in returns[['eur_usd','gbp_usd','usd_jpy','gc','nq','es']]:
    returns[str(c)].plot(figsize=(15, 6))
    plt.xlabel("Date")
    plt.ylabel(c)
    plt.title(f"{str(c)} price of stocks after stationary")
    plt.show()

# %% [markdown]
# In the plots, we can observe a few sudden spikes and examples of volatility clustering.

# %%
for c in returns[['eur_usd','gbp_usd','usd_jpy','gc','nq','es']]:
    plt.figure(1, figsize=(15,6))
    plt.subplot(211)
    plt.title(f"{str(c)} Histogram of returns")
    returns[str(c)].hist()
    plt.subplot(212)
    returns[str(c)].plot(kind='kde')
    
    plt.title(f"{str(c)} Kernal Density Estimator of returns")
    plt.show()

# %%
# !pip install arch
from arch import arch_model
# Out:
# Collecting arch
#   Downloading https://files.pythonhosted.org/packages/7f/5c/ef80e96f2cdc6c2d293b7e4688888a4428963c966fbb0c749c9078e68bb6/arch-4.15-cp36-cp36m-manylinux1_x86_64.whl (790kB)
#      |████████████████████████████████| 798kB 4.8MB/s
# Requirement already satisfied: cython>=0.29.14 in /usr/local/lib/python3.6/dist-packages (from arch) (0.29.21)
# Requirement already satisfied: scipy>=1.0.1 in /usr/local/lib/python3.6/dist-packages (from arch) (1.4.1)
# Requirement already satisfied: numpy>=1.14 in /usr/local/lib/python3.6/dist-packages (from arch) (1.18.5)
# Requirement already satisfied: pandas>=0.23 in /usr/local/lib/python3.6/dist-packages (from arch) (1.1.3)
# Requirement already satisfied: statsmodels>=0.9 in /usr/local/lib/python3.6/dist-packages (from arch) (0.10.2)
# Collecting property-cached>=1.6.3
#   Downloading https://files.pythonhosted.org/packages/5c/6c/94d8e520b20a2502e508e1c558f338061cf409cbee78fd6a3a5c6ae812bd/property_cached-1.6.4-py2.py3-none-any.whl
# Requirement already satisfied: pytz>=2017.2 in /usr/local/lib/python3.6/dist-packages (from pandas>=0.23->arch) (2018.9)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.6/dist-packages (from pandas>=0.23->arch) (2.8.1)
# Requirement already satisfied: patsy>=0.4.0 in /usr/local/lib/python3.6/dist-packages (from statsmodels>=0.9->arch) (0.5.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.6/dist-packages (from python-dateutil>=2.7.3->pandas>=0.23->arch) (1.15.0)
# Installing collected packages: property-cached, arch
# Successfully installed arch-4.15 property-cached-1.6.4

# %% [markdown]
# # CCC-GARCH model for multivariate volatility forecasting

# %%
# lists for storing objects:
coeffs = []
cond_vol = []
std_resids = []
models = []

# %%
# Estimate the univariate GARCH models:
for asset in returns.columns:
  model = arch_model(returns['eur_usd'], mean='Constant', vol='GARCH', p=1, o=0,
                     q=1).fit(update_freq=0, disp='off')
  coeffs.append(model.params)
  cond_vol.append(model.conditional_volatility)
  std_resids.append(model.resid / model.conditional_volatility)
  models.append(model)

# %%
# Store the results in DataFrames:
coeffs_df = pd.DataFrame(coeffs, index=returns.columns)
cond_vol_df = pd.DataFrame(cond_vol).transpose().set_axis(returns.columns, axis='columns', inplace=False)
std_resids_df = pd.DataFrame(std_resids).transpose().set_axis(returns.columns, axis='columns', inplace=False)

# %%
# table containing the estimated coefficients for each series:
coeffs_df
# Out:
#                mu     omega  alpha[1]   beta[1]
# es       0.061194  0.109859       0.0  0.321801
# eur_usd  0.061194  0.109859       0.0  0.321801
# gbp_usd  0.061194  0.109859       0.0  0.321801
# gc       0.061194  0.109859       0.0  0.321801
# nq       0.061194  0.109859       0.0  0.321801
# usd_jpy  0.061194  0.109859       0.0  0.321801

# %%
# constant conditional correlation matrix (R):
R = std_resids_df.transpose().dot(std_resids_df).div(len(std_resids_df))

# one-step-ahead forecast of the conditional covariance matrix:
diag = []
n = (6)
D = np.zeros((n,n))
for model in models:
  diag.append(model.forecast(horizon=1).variance.values[-1][0])
diag = np.sqrt(np.array(diag))
np.fill_diagonal(D, diag)
H = np.matmul(np.matmul(D, R.values), D)

# %%
pd.DataFrame(H, columns = returns.columns)
# Out:
#          es   eur_usd   gbp_usd        gc        nq   usd_jpy
# 0  0.160543  0.160543  0.160543  0.160543  0.160543  0.160543
# 1  0.160543  0.160543  0.160543  0.160543  0.160543  0.160543
# 2  0.160543  0.160543  0.160543  0.160543  0.160543  0.160543
# 3  0.160543  0.160543  0.160543  0.160543  0.160543  0.160543
# 4  0.160543  0.160543  0.160543  0.160543  0.160543  0.160543
# 5  0.160543  0.160543  0.160543  0.160543  0.160543  0.160543

# %%
X = data[['gbp_usd']]

# split into train/test
nobs = 10
train, test = X[:-nobs], X[-nobs:]

# %%
model = arch_model(train, mean='Zero', vol='GARCH', p=12, q=12)

"""
mean='Zero'. 
model for the variance: vol='GARCH'. 
lag parameter for the GARCH model: p=12, q=12
"""
results = model.fit()
print(results.summary())
# Out:
# /usr/local/lib/python3.6/dist-packages/arch/univariate/base.py:293: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 1.078e+08. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 0.001 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   data_scale_warning.format(orig_scale, rescale), DataScaleWarning
# Iteration:      1,   Func. Count:     27,   Neg. LLF: 169.92117943935605
# Iteration:      2,   Func. Count:     56,   Neg. LLF: 169.92115333432315
# Iteration:      3,   Func. Count:     83,   Neg. LLF: 169.92115155381984
# Iteration:      4,   Func. Count:    110,   Neg. LLF: 169.92114941097606
# Iteration:      5,   Func. Count:    137,   Neg. LLF: 169.9211456948745
# Iteration:      6,   Func. Count:    164,   Neg. LLF: 169.921138566824
# Iteration:      7,   Func. Count:    191,   Neg. LLF: 169.92110754763763
# Iteration:      8,   Func. Count:    218,   Neg. LLF: 169.9210287249596
# Iteration:      9,   Func. Count:    245,   Neg. LLF: 169.9210259852951
# Iteration:     10,   Func. Count:    272,   Neg. LLF: 169.9210124530761
# Iteration:     11,   Func. Count:    299,   Neg. LLF: 169.9210057386611
# Iteration:     12,   Func. Count:    326,   Neg. LLF: 169.92098581789122
# Iteration:     13,   Func. Count:    353,   Neg. LLF: 169.92098097434652
# Iteration:     14,   Func. Count:    380,   Neg. LLF: 169.9209581880806
# Iteration:     15,   Func. Count:    407,   Neg. LLF: 169.9209538447878
# Iteration:     16,   Func. Count:    434,   Neg. LLF: 169.92095155282317
# Iteration:     17,   Func. Count:    461,   Neg. LLF: 169.92094842678216
# Iteration:     18,   Func. Count:    488,   Neg. LLF: 169.92094678249006
# Iteration:     19,   Func. Count:    515,   Neg. LLF: 169.9209451368051
# Iteration:     20,   Func. Count:    542,   Neg. LLF: 169.92094303535325
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 169.9209430353483
#             Iterations: 20
#             Function evaluations: 542
#             Gradient evaluations: 20
#                        Zero Mean - GARCH Model Results
# ==============================================================================
# Dep. Variable:                gbp_usd   R-squared:                       0.000
# Mean Model:                 Zero Mean   Adj. R-squared:                  0.091
# Vol Model:                      GARCH   Log-Likelihood:               -169.921
# Distribution:                  Normal   AIC:                           389.842
# Method:            Maximum Likelihood   BIC:                           399.789
#                                         No. Observations:                   11
# Date:                Sun, Nov 01 2020   Df Residuals:                      -14
# Time:                        06:52:32   Df Model:                           25
#                                Volatility Model
# =============================================================================
#                  coef    std err          t      P>|t|       95.0% Conf. Int.
# -----------------------------------------------------------------------------
# omega      7.6546e+11  2.522e+13  3.035e-02      0.976 [-4.867e+13,5.020e+13]
# alpha[1]       0.2956      4.687  6.307e-02      0.950      [ -8.890,  9.481]
# alpha[2]       0.1322        nan        nan        nan      [    nan,    nan]
# alpha[3]       0.0556        nan        nan        nan      [    nan,    nan]
# alpha[4]   3.0096e-19        nan        nan        nan      [    nan,    nan]
# alpha[5]   4.7741e-19      7.503  6.363e-20      1.000      [-14.705, 14.705]
# alpha[6]   5.7294e-19        nan        nan        nan      [    nan,    nan]
# alpha[7]   1.0373e-18      9.876  1.050e-19      1.000      [-19.358, 19.358]
# alpha[8]   1.6426e-18        nan        nan        nan      [    nan,    nan]
# alpha[9]   1.5030e-18      7.785  1.931e-19      1.000      [-15.258, 15.258]
# alpha[10]      0.0000     12.569      0.000      1.000      [-24.636, 24.636]
# alpha[11]  1.1431e-18        nan        nan        nan      [    nan,    nan]
# alpha[12]  5.1623e-19        nan        nan        nan      [    nan,    nan]
# beta[1]        0.0000      6.111      0.000      1.000      [-11.978, 11.978]
# beta[2]    1.3357e-04        nan        nan        nan      [    nan,    nan]
# beta[3]    3.7435e-03      3.987  9.390e-04      0.999      [ -7.810,  7.818]
# beta[4]        0.0110     10.589  1.035e-03      0.999      [-20.743, 20.765]
# beta[5]    2.8001e-18        nan        nan        nan      [    nan,    nan]
# beta[6]    2.9078e-18     18.966  1.533e-19      1.000      [-37.172, 37.172]
# beta[7]    2.3921e-18     18.573  1.288e-19      1.000      [-36.402, 36.402]
# beta[8]        0.0000     11.469      0.000      1.000      [-22.478, 22.478]
# beta[9]    1.5764e-18      7.400  2.130e-19      1.000      [-14.504, 14.504]
# beta[10]       0.0000        nan        nan        nan      [    nan,    nan]
# beta[11]       0.0000   1998.526      0.000      1.000 [-3.917e+03,3.917e+03]
# beta[12]       0.0000  9.934e+05      0.000      1.000 [-1.947e+06,1.947e+06]
# =============================================================================
#
# Covariance estimator: robust
# /usr/local/lib/python3.6/dist-packages/arch/univariate/base.py:1839: RuntimeWarning: invalid value encountered in sqrt
#   np.sqrt(np.diag(self.param_cov)), index=self._names, name="std_err"
# /usr/local/lib/python3.6/dist-packages/scipy/stats/_distn_infrastructure.py:903: RuntimeWarning: invalid value encountered in greater
#   return (a < x) & (x < b)
# /usr/local/lib/python3.6/dist-packages/scipy/stats/_distn_infrastructure.py:903: RuntimeWarning: invalid value encountered in less
#   return (a < x) & (x < b)
# /usr/local/lib/python3.6/dist-packages/scipy/stats/_distn_infrastructure.py:1912: RuntimeWarning: invalid value encountered in less_equal
#   cond2 = cond0 & (x <= _a)

# %%
# forecast the test set
yhat = model_fit.forecast(horizon=nobs)
# plot the actual variance
var = [i*0.01 for i in range(0,100)]
plt.plot(var[-nobs:])
# plot forecast variance
plt.plot(yhat.variance.values[-1, :])
plt.show()

# %% [markdown]
# ## GBPUSD Predicted Variance

# %%
test.rolling(window=5).var().plot(style='g')
plt.title("5-day Rolling Variance")
plt.show()

# %%
plt.plot(yhat.variance.values[-1, :])
plt.title("Predicted Variance")
plt.show()

# %% [markdown]
# We see that the GARCH model predicts a drop in volatility for the last 10 days (as measured by variance) — this is confirmed by a visual inspection of the actual 5-day rolling variance.
#
# ## GARCH Model USDJPY

# %%
X = data[['usd_jpy']]

# split into train/test
nobs = 10
train, test = X[:-nobs], X[-nobs:]

# %%
# define model
model = arch_model(returns['gbp_usd'], mean='Zero', vol='GARCH', p=15, q=15)
model
# Out:
# Zero Mean(constant: no, no. of exog: 0, volatility: GARCH(p: 15, q: 15), distribution: Normal distribution), id: 0x7fbda7061080

# %%
# fit model
model_fit = model.fit()
# forecast the test set
yhat = model_fit.forecast(horizon=nobs)
# Out:
# Iteration:      1,   Func. Count:     33,   Neg. LLF: 18.600354784377508
# Iteration:      2,   Func. Count:     67,   Neg. LLF: 17.14418237887373
# Iteration:      3,   Func. Count:    101,   Neg. LLF: 16.250010955627882
# Iteration:      4,   Func. Count:    135,   Neg. LLF: 15.966662258118662
# Iteration:      5,   Func. Count:    168,   Neg. LLF: 15.841011970407658
# Iteration:      6,   Func. Count:    202,   Neg. LLF: 14.8684934426118
# Iteration:      7,   Func. Count:    236,   Neg. LLF: 14.817565696987177
# Iteration:      8,   Func. Count:    269,   Neg. LLF: 14.483718535246915
# Iteration:      9,   Func. Count:    303,   Neg. LLF: 14.388726005496556
# Iteration:     10,   Func. Count:    337,   Neg. LLF: 14.204369084282092
# Iteration:     11,   Func. Count:    370,   Neg. LLF: 14.094338954127775
# Iteration:     12,   Func. Count:    404,   Neg. LLF: 14.067400383951986
# Iteration:     13,   Func. Count:    437,   Neg. LLF: 14.060453169967113
# Iteration:     14,   Func. Count:    470,   Neg. LLF: 14.0573554476166
# Iteration:     15,   Func. Count:    503,   Neg. LLF: 14.056219434416965
# Iteration:     16,   Func. Count:    536,   Neg. LLF: 14.056074337924455
# Iteration:     17,   Func. Count:    569,   Neg. LLF: 14.056018698770215
# Iteration:     18,   Func. Count:    602,   Neg. LLF: 14.055938944849581
# Iteration:     19,   Func. Count:    635,   Neg. LLF: 14.055851429719349
# Iteration:     20,   Func. Count:    668,   Neg. LLF: 14.055819042449418
# Iteration:     21,   Func. Count:    701,   Neg. LLF: 14.055814435944795
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 14.05581429551517
#             Iterations: 21
#             Function evaluations: 701
#             Gradient evaluations: 21

# %% [markdown]
# ## Comparison of Predicted Variance and actual 5-day Rolling Variance

# %%
# Rolling Window
test.rolling(window=5).var().plot(style='g')
plt.title("5-day Rolling Variance")
plt.show()

# %%
# plot forecast variance
plt.plot(yhat.variance.values[-1, :])
plt.title("Predicted Variance")
plt.show()

# %% [markdown]
# Ref: https://vlab.stern.nyu.edu/docs/correlation/GARCH-DCC

# %%
forecasts = results.forecast(horizon=30, method='simulation', simulations=1000)
sims = forecasts.simulations

lines = plt.plot(sims.values[-1,:,:].T, color='blue', alpha=0.01)
lines[0].set_label('Simulated paths')
plt.show()

# %%
print(np.percentile(sims.values[-1,:,-1].T,5))
plt.hist(sims.values[-1, :,-1],bins=50)
plt.title('Distribution of Returns')
plt.show()
# Out:
# -1.0427653021266803

# %%
# !pip install pmdarima
import pmdarima
import arch

# fit ARIMA on returns 
arima_model_fitted = pmdarima.auto_arima(train)
p, d, q = arima_model.order
arima_residuals = arima_model.arima_res_.resid

# fit a GARCH(1,1) model on the residuals of the ARIMA model
garch = arch.arch_model(arima_residuals, p=1, q=1)
garch_fitted = garch.fit()

# Use ARIMA to predict mu
predicted_mu = arima_model.predict(n_periods=1)[0]
# Use GARCH to predict the residual
garch_forecast = garch_model.forecast(horizon=1)
predicted_et = garch_forecast.mean['h.1'].iloc[-1]
# Combine both models' output: yt = mu + et
prediction = predicted_mu + predicted_et
